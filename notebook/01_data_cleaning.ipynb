# %% [markdown]
# ### IMPORT THE FILES PATH ###
# ### CLEAN THE DATA

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
acct = pd.read_csv(r"C:\Users\Ifeoluwa\OneDrive\Documents\Finlora\data\raw\finlora_accounts.csv")
txn = pd.read_csv(r"C:\Users\Ifeoluwa\OneDrive\Documents\Finlora\data\raw\finlora_transactions.csv")

# %%
acct.head()
# Out:
#        account_id account_holder_name account_type home_country currency  \
# 0  FLR-ACC-100000        Amaka Okafor   Individual           NG      NGN
# 1  FLR-ACC-100001  Bluewave Foods Ltd     Business           NG      NGN
# 2  FLR-ACC-100002  Global Trading LLC     Business           US      USD
# 3  FLR-ACC-100003        Femi Adeyemi   Individual           NG      NGN
# 4  FLR-ACC-100004         Ngozi Brown   Individual           NG      NGN
#
#          kyc_tier account_created_date  personal_spend_baseline_usd
# 0  Tier3_Enhanced           2022-08-28                        63.23
# 1     Tier1_Basic           2026-04-27                       810.68
# 2  Tier2_Verified           2026-03-29                       433.67
# 3  Tier3_Enhanced           2025-09-15                        19.18
# 4  Tier3_Enhanced           2024-06-18                        28.68

# %%
acct.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7200 entries, 0 to 7199
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   account_id                   7200 non-null   str
#  1   account_holder_name          7200 non-null   str
#  2   account_type                 7200 non-null   str
#  3   home_country                 7200 non-null   str
#  4   currency                     7200 non-null   str
#  5   kyc_tier                     7200 non-null   str
#  6   account_created_date         7200 non-null   str
#  7   personal_spend_baseline_usd  7200 non-null   float64
# dtypes: float64(1), str(7)
# memory usage: 450.1 KB

# %%
acct.isnull().sum()
# Out:
# account_id                     0
# account_holder_name            0
# account_type                   0
# home_country                   0
# currency                       0
# kyc_tier                       0
# account_created_date           0
# personal_spend_baseline_usd    0
# dtype: int64

# %%
acct.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in ['account_holder_name', 'personal_spend_baseline_usd', 'account_type']:
    print(col, acct[col].unique())
    print()
# Out:
# account_holder_name <StringArray>
# [            'Amaka Okafor',       'Bluewave Foods Ltd',
#        'Global Trading LLC',             'Femi Adeyemi',
#               'Ngozi Brown',  'Global Technologies Co.',
#                 'Olu Bello',          'North Foods Co.',
#   'Greenfield Textiles Ltd',            'David Johnson',
#  ...
#       'Global Builders LLC',       'Prime Builders Co.',
#       'Prime Logistics Co.',                'Ben Smith',
#  'Greenfield Logistics Co.',     'Greenfield Media LLC',
#        'Prime Textiles Inc',      'Global Textiles Ltd',
#              'Musa Ibrahim',       'Prime Textiles Ltd']
# Length: 1000, dtype: str
#
# personal_spend_baseline_usd [  63.23  810.68  433.67 ... 1617.25   28.02  153.79]
#
# account_type <StringArray>
# ['Individual', 'Business']
# Length: 2, dtype: str

# %%
txn.head()
# Out:
#     transaction_id      account_id account_type        kyc_tier  \
# 0  FLR250216186265  FLR-ACC-100000   Individual  Tier3_Enhanced
# 1  FLR250423143305  FLR-ACC-100000   Individual  Tier3_Enhanced
# 2  FLR250424154897  FLR-ACC-100000   Individual  Tier3_Enhanced
# 3  FLR250428101772  FLR-ACC-100000   Individual  Tier3_Enhanced
# 4  FLR250628102827  FLR-ACC-100000   Individual  Tier3_Enhanced
#
#              timestamp day_of_week  hour_of_day  \
# 0  2025-02-16 14:55:35      Sunday           14
# 1  2025-04-23 13:35:40   Wednesday           13
# 2  2025-04-24 12:30:34    Thursday           12
# 3  2025-04-28 14:41:59      Monday           14
# 4  2025-06-28 16:15:47    Saturday           16
#
#                              description         merchant_name  \
# 0                    CNP PURCHASE - BOLT                  Bolt
# 1                   WEB PURCHASE - SLACK                 Slack
# 2  MOBILE PURCHASE - JUSTRITE SUPERSTORE   Justrite Superstore
# ...

# %%
txn.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 126000 entries, 0 to 125999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   transaction_id              126000 non-null  str
#  1   account_id                  126000 non-null  str
#  2   account_type                126000 non-null  str
#  3   kyc_tier                    126000 non-null  str
#  4   timestamp                   126000 non-null  str
#  5   day_of_week                 126000 non-null  str
#  6   hour_of_day                 126000 non-null  int64
#  7   description                 126000 non-null  str
#  8   merchant_name               97390 non-null   str
#  9   merchant_category           126000 non-null  str
#  10  channel                     126000 non-null  str
#  11  amount                      126000 non-null  float64
#  12  currency                    126000 non-null  str
# ...

# %%
txn.isnull().sum()
# Out:
# transaction_id                    0
# account_id                        0
# account_type                      0
# kyc_tier                          0
# timestamp                         0
# day_of_week                       0
# hour_of_day                       0
# description                       0
# merchant_name                 28610
# merchant_category                 0
# channel                           0
# amount                            0
# currency                          0
# amount_to_avg_ratio               0
# avg_transaction_amount_30d        0
# transaction_velocity_1h           0
# transaction_country               0
# home_country                      0
# is_cross_border                   0
# device_id                     14334
# is_new_device                 14334
# account_age_days                  0
# status                            0
# is_fraud                          0
# dtype: int64

# %%
txn.duplicated().sum()
# Out:
# np.int64(0)

# %%
txn['merchant_name'].value_counts().head(10)
# Out:
# merchant_name
# International Wire    7584
# Jumia                 2365
# Apple Store Online    2311
# Zara                  2279
# ASOS                  2264
# Amazon                2233
# Konga                 2192
# British Gas           2135
# EEDC                  2112
# Thames Water          2059
# Name: count, dtype: int64

# %%
txn.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 126000 entries, 0 to 125999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   transaction_id              126000 non-null  str
#  1   account_id                  126000 non-null  str
#  2   account_type                126000 non-null  str
#  3   kyc_tier                    126000 non-null  str
#  4   timestamp                   126000 non-null  str
#  5   day_of_week                 126000 non-null  str
#  6   hour_of_day                 126000 non-null  int64
#  7   description                 126000 non-null  str
#  8   merchant_name               97390 non-null   str
#  9   merchant_category           126000 non-null  str
#  10  channel                     126000 non-null  str
#  11  amount                      126000 non-null  float64
#  12  currency                    126000 non-null  str
# ...

# %%
txn['device_id'] = txn['device_id'].fillna('Unknown_id')

# %%
txn.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 126000 entries, 0 to 125999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   transaction_id              126000 non-null  str
#  1   account_id                  126000 non-null  str
#  2   account_type                126000 non-null  str
#  3   kyc_tier                    126000 non-null  str
#  4   timestamp                   126000 non-null  str
#  5   day_of_week                 126000 non-null  str
#  6   hour_of_day                 126000 non-null  int64
#  7   description                 126000 non-null  str
#  8   merchant_name               97390 non-null   str
#  9   merchant_category           126000 non-null  str
#  10  channel                     126000 non-null  str
#  11  amount                      126000 non-null  float64
#  12  currency                    126000 non-null  str
# ...

# %%
txn.head()
# Out:
#     transaction_id      account_id account_type        kyc_tier  \
# 0  FLR250216186265  FLR-ACC-100000   Individual  Tier3_Enhanced
# 1  FLR250423143305  FLR-ACC-100000   Individual  Tier3_Enhanced
# 2  FLR250424154897  FLR-ACC-100000   Individual  Tier3_Enhanced
# 3  FLR250428101772  FLR-ACC-100000   Individual  Tier3_Enhanced
# 4  FLR250628102827  FLR-ACC-100000   Individual  Tier3_Enhanced
#
#              timestamp day_of_week  hour_of_day  \
# 0  2025-02-16 14:55:35      Sunday           14
# 1  2025-04-23 13:35:40   Wednesday           13
# 2  2025-04-24 12:30:34    Thursday           12
# 3  2025-04-28 14:41:59      Monday           14
# 4  2025-06-28 16:15:47    Saturday           16
#
#                              description         merchant_name  \
# 0                    CNP PURCHASE - BOLT                  Bolt
# 1                   WEB PURCHASE - SLACK                 Slack
# 2  MOBILE PURCHASE - JUSTRITE SUPERSTORE   Justrite Superstore
# ...

# %%
txn['timestamp'] = pd.to_datetime(txn['timestamp'], format='%Y-%m-%d %H:%M:%S')

# %%
txn.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 126000 entries, 0 to 125999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   transaction_id              126000 non-null  str
#  1   account_id                  126000 non-null  str
#  2   account_type                126000 non-null  str
#  3   kyc_tier                    126000 non-null  str
#  4   timestamp                   126000 non-null  datetime64[us]
#  5   day_of_week                 126000 non-null  str
#  6   hour_of_day                 126000 non-null  int64
#  7   description                 126000 non-null  str
#  8   merchant_name               97390 non-null   str
#  9   merchant_category           126000 non-null  str
#  10  channel                     126000 non-null  str
#  11  amount                      126000 non-null  float64
#  12  currency                    126000 non-null  str
# ...

# %%
txn.duplicated().sum()
# Out:
# np.int64(0)

# %%
txn.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 126000 entries, 0 to 125999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   transaction_id              126000 non-null  str
#  1   account_id                  126000 non-null  str
#  2   account_type                126000 non-null  str
#  3   kyc_tier                    126000 non-null  str
#  4   timestamp                   126000 non-null  datetime64[us]
#  5   day_of_week                 126000 non-null  str
#  6   hour_of_day                 126000 non-null  int64
#  7   description                 126000 non-null  str
#  8   merchant_name               97390 non-null   str
#  9   merchant_category           126000 non-null  str
#  10  channel                     126000 non-null  str
#  11  amount                      126000 non-null  float64
#  12  currency                    126000 non-null  str
# ...

# %%
txn.isnull().sum()
# Out:
# transaction_id                    0
# account_id                        0
# account_type                      0
# kyc_tier                          0
# timestamp                         0
# day_of_week                       0
# hour_of_day                       0
# description                       0
# merchant_name                 28610
# merchant_category                 0
# channel                           0
# amount                            0
# currency                          0
# amount_to_avg_ratio               0
# avg_transaction_amount_30d        0
# transaction_velocity_1h           0
# transaction_country               0
# home_country                      0
# is_cross_border                   0
# device_id                         0
# is_new_device                 14334
# account_age_days                  0
# status                            0
# is_fraud                          0
# dtype: int64

# %%
txn.is_new_device.value_counts()
# Out:
# is_new_device
# 0.0    107771
# 1.0      3895
# Name: count, dtype: int64

# %%
print(txn.columns.tolist())
# Out:
# ['transaction_id', 'account_id', 'account_type', 'kyc_tier', 'timestamp', 'day_of_week', 'hour_of_day', 'description', 'merchant_name', 'merchant_category', 'channel', 'amount', 'currency', 'amount_to_avg_ratio', 'avg_transaction_amount_30d', 'transaction_velocity_1h', 'transaction_country', 'home_country', 'is_cross_border', 'device_id', 'is_new_device', 'account_age_days', 'status', 'is_fraud']

# %%
txn.duplicated().sum()
# Out:
# np.int64(0)

# %%
txn.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 126000 entries, 0 to 125999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   transaction_id              126000 non-null  str
#  1   account_id                  126000 non-null  str
#  2   account_type                126000 non-null  str
#  3   kyc_tier                    126000 non-null  str
#  4   timestamp                   126000 non-null  datetime64[us]
#  5   day_of_week                 126000 non-null  str
#  6   hour_of_day                 126000 non-null  int64
#  7   description                 126000 non-null  str
#  8   merchant_name               97390 non-null   str
#  9   merchant_category           126000 non-null  str
#  10  channel                     126000 non-null  str
#  11  amount                      126000 non-null  float64
#  12  currency                    126000 non-null  str
# ...

# %%
txn.isnull().sum()
# Out:
# transaction_id                    0
# account_id                        0
# account_type                      0
# kyc_tier                          0
# timestamp                         0
# day_of_week                       0
# hour_of_day                       0
# description                       0
# merchant_name                 28610
# merchant_category                 0
# channel                           0
# amount                            0
# currency                          0
# amount_to_avg_ratio               0
# avg_transaction_amount_30d        0
# transaction_velocity_1h           0
# transaction_country               0
# home_country                      0
# is_cross_border                   0
# device_id                         0
# is_new_device                 14334
# account_age_days                  0
# status                            0
# is_fraud                          0
# dtype: int64

# %%
txn['is_new_device'] = txn['is_new_device'].fillna('Unknown_device')

# %%
txn.isnull().sum()
# Out:
# transaction_id                    0
# account_id                        0
# account_type                      0
# kyc_tier                          0
# timestamp                         0
# day_of_week                       0
# hour_of_day                       0
# description                       0
# merchant_name                 28610
# merchant_category                 0
# channel                           0
# amount                            0
# currency                          0
# amount_to_avg_ratio               0
# avg_transaction_amount_30d        0
# transaction_velocity_1h           0
# transaction_country               0
# home_country                      0
# is_cross_border                   0
# device_id                         0
# is_new_device                     0
# account_age_days                  0
# status                            0
# is_fraud                          0
# dtype: int64

# %%
txn['merchant_name'] = txn['merchant_name'].fillna(txn['merchant_category'])

# %%
txn.head(30)
# Out:
#      transaction_id      account_id account_type        kyc_tier  \
# 0   FLR250216186265  FLR-ACC-100000   Individual  Tier3_Enhanced
# 1   FLR250423143305  FLR-ACC-100000   Individual  Tier3_Enhanced
# 2   FLR250424154897  FLR-ACC-100000   Individual  Tier3_Enhanced
# 3   FLR250428101772  FLR-ACC-100000   Individual  Tier3_Enhanced
# 4   FLR250628102827  FLR-ACC-100000   Individual  Tier3_Enhanced
# 5   FLR250826178973  FLR-ACC-100000   Individual  Tier3_Enhanced
# 6   FLR250924142173  FLR-ACC-100000   Individual  Tier3_Enhanced
# 7   FLR250928113373  FLR-ACC-100000   Individual  Tier3_Enhanced
# 8   FLR251118136208  FLR-ACC-100000   Individual  Tier3_Enhanced
# 9   FLR251122148229  FLR-ACC-100000   Individual  Tier3_Enhanced
# 10  FLR251218213918  FLR-ACC-100000   Individual  Tier3_Enhanced
# 11  FLR260531222795  FLR-ACC-100000   Individual  Tier3_Enhanced
# 12  FLR260704180973  FLR-ACC-100000   Individual  Tier3_Enhanced
# ...

# %%
acct.head(2)
# Out:
#        account_id account_holder_name account_type home_country currency  \
# 0  FLR-ACC-100000        Amaka Okafor   Individual           NG      NGN
# 1  FLR-ACC-100001  Bluewave Foods Ltd     Business           NG      NGN
#
#          kyc_tier account_created_date  personal_spend_baseline_usd
# 0  Tier3_Enhanced           2022-08-28                        63.23
# 1     Tier1_Basic           2026-04-27                       810.68

# %%
txn.to_csv(r"C:\Users\Ifeoluwa\OneDrive\Documents\Finlora\data\processed\finlora_transactions_cleaned.csv", index=False)
acct.to_csv(r"C:\Users\Ifeoluwa\OneDrive\Documents\Finlora\data\processed\finlora_accounts_cleaned.csv", index=False)
